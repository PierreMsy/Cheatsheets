# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\pierre\miniconda3\envs\probabl\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
from sklearn.datasets import fetch_openml

from matplotlib import pyplot as plt
import seaborn as sns

# %%
census_data = fetch_openml(name='adult', version=2, as_frame=True)

df_X = census_data.data
s_y = census_data.target

df_dataset = df_X.copy(deep=True)
df_dataset["class"] = s_y

target_column = "class"

# %%
df_X.dtypes
# Out:
# age                  int64
# workclass         category
# fnlwgt               int64
# education         category
# education-num        int64
# marital-status    category
# occupation        category
# relationship      category
# race              category
# sex               category
# capital-gain         int64
# capital-loss         int64
# hours-per-week       int64
# native-country    category
# dtype: object

# %% [markdown]
# numerical feature histogram

# %%
_ = df_X["age"].hist(figsize=(9, 5))

# %% [markdown]
# Pair plot intercation with the target

# %%
n_samples_to_plot = 5000
columns = ["age", "education-num", "hours-per-week"]

_ = sns.pairplot(
    data=df_dataset[:n_samples_to_plot],
    vars=columns,
    hue=target_column,
    plot_kws={"alpha": 0.2},
    height=3,
    diag_kind="hist",
    diag_kws={"bins": 30},
)

# %% [markdown]
# Single pair of variable interaction with the target

# %%
_ = sns.scatterplot(
    x="age",
    y="hours-per-week",
    data=df_dataset[:n_samples_to_plot],
    hue=target_column,
    alpha=0.5,
)
